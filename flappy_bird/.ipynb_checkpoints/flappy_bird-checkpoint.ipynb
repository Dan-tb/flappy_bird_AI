# %%
# importing the necessary libraries
import gym
import numpy as np
from stable_baselines3 import DQN,PPO
from stable_baselines3.common import env_checker
from gym import Env, spaces
import mss
import pydirectinput
import cv2
import time
import matplotlib.pyplot as plt
import pytesseract
from stable_baselines3.common.callbacks import BaseCallback
import os

# %%
# error observed about tesseract installation in path

# tessract installation in computer path
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
# the game environment
class Flappy(Env):
    def __init__(self):
        super().__init__()
        self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(low=0, high=255,
                                            shape=(1, 100, 150),
                                            dtype=np.uint8)
        self.cap = mss.mss()
        self.game_location = {'top':135, 'left':280, 'width':400, 'height':600}
        self.done_location = {'top':230, 'left':330, 'width':300, 'height':70}
        
    def reset(self):
        pydirectinput.click(500,500)
        time.sleep(2)
        pydirectinput.press("space")
        
        return self.get_observation()
    
    def step(self, action):
        action_map = {
            0:"no_op",
            1:"space"
        }
        pydirectinput.press(action_map[action])
        done = self.get_done()
        observation = self.get_observation()
        reward = 1
        info = {}
        
        return observation, reward, done, info
#     state of the environment in form of pictures
    def get_observation(self):
        raw_image = np.array(self.cap.grab(self.game_location))[:,:,:3]
        
        preprocess = cv2.cvtColor(raw_image, cv2.COLOR_BGR2GRAY)
        
        resize = cv2.resize(preprocess, (150,100))
        
        channel = np.reshape(resize, (1, 100, 150))
        
        return channel
    
#     close the windows
    def close(self):
        cv2.destroyAllWindows()
        
#     get the done image
    def get_done(self):
        done_image = np.array(self.cap.grab(self.done_location))[:,:,:3]
        gray_image = cv2.cvtColor(done_image, cv2.COLOR_BGR2GRAY)
        done = False
#         game_over = 'i Te\n'
        game_over = ''
        image_string = pytesseract.image_to_string(gray_image)
        if image_string is game_over:
            print(image_string)
            done = True
            
        return done

# %%
cap = mss.mss()
done_location = {'top':230, 'left':330, 'width':300, 'height':70}
done_image = np.array(cap.grab(done_location))[:,:,:3]
# gray_image = cv2.cvtColor(done_image, cv2.COLOR_BGR2GRAY)

image_string = pytesseract.image_to_string(done_image)

# plt.imshow(done_image)
image_string
# Out:
# ''

# %%
# initialise the game environment
game = Flappy()

# %%
game.reset()
# Out:
# array([[[255, 255, 255, ..., 255, 255, 255],
#         [159, 159, 159, ..., 159, 159, 159],
#         [159, 159, 159, ..., 159, 159, 159],
#         ...,
#         [210, 210, 210, ..., 210, 210, 210],
#         [210, 210, 210, ..., 210, 210, 210],
#         [210, 210, 210, ..., 210, 210, 210]]], dtype=uint8)

# %%
game.close()

# %%
plt.imshow(game.get_observation()[0])

# %%
# creating the callback class
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super().__init__(TrainAndLoggingCallback)
        self.check_freq = check_freq
        self.save_path = save_path
        
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best model_{}'.format(self.n_calls))
            self.model.save(model_path)
        return True

# %%
# creating log and checkpoint directory
log_dir = './logs/'
checkpoint_dir = './train/'

# %%
# initialising the callback class
callback = TrainAndLoggingCallback(check_freq=1000, save_path=checkpoint_dir)

# %%
# setting the policy
agent = DQN("CnnPolicy", game, tensorboard_log=log_dir, verbose=1, buffer_size=100000, learning_starts=1000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
env_checker.check_env(game)

# %%
agent.learn(total_timesteps=5000, callback=callback)
# Out:
# Logging to ./logs/DQN_3
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 0        |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 4        |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 0        |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 8        |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 0        |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 12       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 0        |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 16       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 0        |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 20       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 0        |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 24       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 0        |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 28       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 0        |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 32       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 0        |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 36       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 0        |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 40       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 0        |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 44       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 0        |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 48       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 0        |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 52       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 0        |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 56       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 0        |
# |    time_elapsed     | 191      |
# |    total_timesteps  | 60       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 0        |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 64       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 0        |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 68       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 0        |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 72       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 0        |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 76       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 0        |
# |    time_elapsed     | 254      |
# |    total_timesteps  | 80       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 0        |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 84       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 0        |
# |    time_elapsed     | 279      |
# |    total_timesteps  | 88       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 0        |
# |    time_elapsed     | 292      |
# |    total_timesteps  | 92       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 0        |
# |    time_elapsed     | 305      |
# |    total_timesteps  | 96       |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 0        |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 103      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 0        |
# |    time_elapsed     | 332      |
# |    total_timesteps  | 107      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 0        |
# |    time_elapsed     | 344      |
# |    total_timesteps  | 111      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 0        |
# |    time_elapsed     | 359      |
# |    total_timesteps  | 118      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 0        |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 122      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 0        |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 126      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 0        |
# |    time_elapsed     | 397      |
# |    total_timesteps  | 130      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.745    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 0        |
# |    time_elapsed     | 409      |
# |    total_timesteps  | 134      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 0        |
# |    time_elapsed     | 422      |
# |    total_timesteps  | 138      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.73     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 0        |
# |    time_elapsed     | 434      |
# |    total_timesteps  | 142      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 0        |
# |    time_elapsed     | 447      |
# |    total_timesteps  | 146      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 0        |
# |    time_elapsed     | 459      |
# |    total_timesteps  | 150      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 0        |
# |    time_elapsed     | 472      |
# |    total_timesteps  | 154      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.7      |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 0        |
# |    time_elapsed     | 484      |
# |    total_timesteps  | 158      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.692    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 0        |
# |    time_elapsed     | 497      |
# |    total_timesteps  | 162      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.685    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 0        |
# |    time_elapsed     | 510      |
# |    total_timesteps  | 166      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.677    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 0        |
# |    time_elapsed     | 522      |
# |    total_timesteps  | 170      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 0        |
# |    time_elapsed     | 535      |
# |    total_timesteps  | 174      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.662    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 0        |
# |    time_elapsed     | 547      |
# |    total_timesteps  | 178      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.654    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 0        |
# |    time_elapsed     | 560      |
# |    total_timesteps  | 182      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.647    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 0        |
# |    time_elapsed     | 573      |
# |    total_timesteps  | 186      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 0        |
# |    time_elapsed     | 585      |
# |    total_timesteps  | 190      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 0        |
# |    time_elapsed     | 598      |
# |    total_timesteps  | 194      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.624    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 0        |
# |    time_elapsed     | 610      |
# |    total_timesteps  | 198      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.616    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 0        |
# |    time_elapsed     | 623      |
# |    total_timesteps  | 202      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.609    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 0        |
# |    time_elapsed     | 636      |
# |    total_timesteps  | 206      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 0        |
# |    time_elapsed     | 648      |
# |    total_timesteps  | 210      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 0        |
# |    time_elapsed     | 661      |
# |    total_timesteps  | 214      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.586    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 0        |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 218      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.578    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 0        |
# |    time_elapsed     | 686      |
# |    total_timesteps  | 222      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.571    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 0        |
# |    time_elapsed     | 698      |
# |    total_timesteps  | 226      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.563    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 0        |
# |    time_elapsed     | 711      |
# |    total_timesteps  | 230      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 0        |
# |    time_elapsed     | 724      |
# |    total_timesteps  | 234      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 0        |
# |    time_elapsed     | 736      |
# |    total_timesteps  | 238      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.54     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 0        |
# |    time_elapsed     | 749      |
# |    total_timesteps  | 242      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.533    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 0        |
# |    time_elapsed     | 762      |
# |    total_timesteps  | 246      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 0        |
# |    time_elapsed     | 775      |
# |    total_timesteps  | 251      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.515    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 0        |
# |    time_elapsed     | 787      |
# |    total_timesteps  | 255      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.508    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 0        |
# |    time_elapsed     | 800      |
# |    total_timesteps  | 259      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.5      |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 0        |
# |    time_elapsed     | 813      |
# |    total_timesteps  | 263      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.493    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 0        |
# |    time_elapsed     | 825      |
# |    total_timesteps  | 267      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.485    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 0        |
# |    time_elapsed     | 838      |
# |    total_timesteps  | 271      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.477    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 0        |
# |    time_elapsed     | 850      |
# |    total_timesteps  | 275      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.47     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 0        |
# |    time_elapsed     | 863      |
# |    total_timesteps  | 279      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.46     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 0        |
# |    time_elapsed     | 876      |
# |    total_timesteps  | 284      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.453    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 0        |
# |    time_elapsed     | 888      |
# |    total_timesteps  | 288      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 0        |
# |    time_elapsed     | 901      |
# |    total_timesteps  | 292      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.438    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 0        |
# |    time_elapsed     | 914      |
# |    total_timesteps  | 296      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 0        |
# |    time_elapsed     | 926      |
# |    total_timesteps  | 300      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.422    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 0        |
# |    time_elapsed     | 939      |
# |    total_timesteps  | 304      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 0        |
# |    time_elapsed     | 951      |
# |    total_timesteps  | 308      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.407    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 0        |
# |    time_elapsed     | 964      |
# |    total_timesteps  | 312      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 0        |
# |    time_elapsed     | 977      |
# |    total_timesteps  | 316      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.392    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 0        |
# |    time_elapsed     | 989      |
# |    total_timesteps  | 320      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.384    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 0        |
# |    time_elapsed     | 1002     |
# |    total_timesteps  | 324      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.377    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 0        |
# |    time_elapsed     | 1014     |
# |    total_timesteps  | 328      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 0        |
# |    time_elapsed     | 1027     |
# |    total_timesteps  | 332      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.362    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 0        |
# |    time_elapsed     | 1039     |
# |    total_timesteps  | 336      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.354    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 0        |
# |    time_elapsed     | 1052     |
# |    total_timesteps  | 340      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.346    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 0        |
# |    time_elapsed     | 1065     |
# |    total_timesteps  | 344      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 0        |
# |    time_elapsed     | 1077     |
# |    total_timesteps  | 348      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 0        |
# |    time_elapsed     | 1090     |
# |    total_timesteps  | 352      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.324    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 0        |
# |    time_elapsed     | 1103     |
# |    total_timesteps  | 356      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 0        |
# |    time_elapsed     | 1115     |
# |    total_timesteps  | 360      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 0        |
# |    time_elapsed     | 1128     |
# |    total_timesteps  | 364      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.301    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 0        |
# |    time_elapsed     | 1140     |
# |    total_timesteps  | 368      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 0        |
# |    time_elapsed     | 1153     |
# |    total_timesteps  | 372      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.286    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 0        |
# |    time_elapsed     | 1165     |
# |    total_timesteps  | 376      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.278    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 0        |
# |    time_elapsed     | 1178     |
# |    total_timesteps  | 380      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 0        |
# |    time_elapsed     | 1191     |
# |    total_timesteps  | 384      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.263    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 0        |
# |    time_elapsed     | 1203     |
# |    total_timesteps  | 388      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.255    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 0        |
# |    time_elapsed     | 1216     |
# |    total_timesteps  | 392      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.248    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 0        |
# |    time_elapsed     | 1228     |
# |    total_timesteps  | 396      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 0        |
# |    time_elapsed     | 1241     |
# |    total_timesteps  | 400      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.232    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 0        |
# |    time_elapsed     | 1253     |
# |    total_timesteps  | 404      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.225    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 0        |
# |    time_elapsed     | 1266     |
# |    total_timesteps  | 408      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.217    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 0        |
# |    time_elapsed     | 1278     |
# |    total_timesteps  | 412      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1        |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.21     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 0        |
# |    time_elapsed     | 1291     |
# |    total_timesteps  | 416      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.196    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 0        |
# |    time_elapsed     | 1305     |
# |    total_timesteps  | 423      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.189    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 0        |
# |    time_elapsed     | 1318     |
# |    total_timesteps  | 427      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.181    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 0        |
# |    time_elapsed     | 1330     |
# |    total_timesteps  | 431      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.174    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 0        |
# |    time_elapsed     | 1343     |
# |    total_timesteps  | 435      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.166    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 0        |
# |    time_elapsed     | 1356     |
# |    total_timesteps  | 439      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.158    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 0        |
# |    time_elapsed     | 1368     |
# |    total_timesteps  | 443      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.151    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 0        |
# |    time_elapsed     | 1381     |
# |    total_timesteps  | 447      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.143    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 0        |
# |    time_elapsed     | 1393     |
# |    total_timesteps  | 451      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.136    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 0        |
# |    time_elapsed     | 1406     |
# |    total_timesteps  | 455      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.128    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 0        |
# |    time_elapsed     | 1418     |
# |    total_timesteps  | 459      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.12     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 0        |
# |    time_elapsed     | 1431     |
# |    total_timesteps  | 463      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.113    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 0        |
# |    time_elapsed     | 1444     |
# |    total_timesteps  | 467      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.105    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 0        |
# |    time_elapsed     | 1456     |
# |    total_timesteps  | 471      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.0975   |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 0        |
# |    time_elapsed     | 1469     |
# |    total_timesteps  | 475      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.0899   |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 0        |
# |    time_elapsed     | 1481     |
# |    total_timesteps  | 479      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.0823   |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 0        |
# |    time_elapsed     | 1494     |
# |    total_timesteps  | 483      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.0747   |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 0        |
# |    time_elapsed     | 1506     |
# |    total_timesteps  | 487      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.0671   |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 0        |
# |    time_elapsed     | 1519     |
# |    total_timesteps  | 491      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.0595   |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 0        |
# |    time_elapsed     | 1532     |
# |    total_timesteps  | 495      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.0519   |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 0        |
# |    time_elapsed     | 1544     |
# |    total_timesteps  | 499      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 0        |
# |    time_elapsed     | 1557     |
# |    total_timesteps  | 503      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# ...
# | rollout/            |          |
# |    ep_len_mean      | 1.08     |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1852     |
# |    fps              | 0        |
# |    time_elapsed     | 6016     |
# |    total_timesteps  | 2063     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000147 |
# |    n_updates        | 265      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.08     |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1856     |
# |    fps              | 0        |
# |    time_elapsed     | 6029     |
# |    total_timesteps  | 2067     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00013  |
# |    n_updates        | 266      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07     |
# |    ep_rew_mean      | 1.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1860     |
# |    fps              | 0        |
# |    time_elapsed     | 6042     |
# |    total_timesteps  | 2071     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000112 |
# |    n_updates        | 267      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07     |
# |    ep_rew_mean      | 1.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1864     |
# |    fps              | 0        |
# |    time_elapsed     | 6055     |
# |    total_timesteps  | 2075     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000126 |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.08     |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1868     |
# |    fps              | 0        |
# |    time_elapsed     | 6069     |
# |    total_timesteps  | 2080     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000124 |
# |    n_updates        | 269      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.08     |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1872     |
# |    fps              | 0        |
# |    time_elapsed     | 6082     |
# |    total_timesteps  | 2084     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.75e-05 |
# |    n_updates        | 270      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1876     |
# |    fps              | 0        |
# |    time_elapsed     | 6095     |
# |    total_timesteps  | 2088     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000224 |
# |    n_updates        | 271      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1880     |
# |    fps              | 0        |
# |    time_elapsed     | 6108     |
# |    total_timesteps  | 2092     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000251 |
# |    n_updates        | 272      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1884     |
# |    fps              | 0        |
# |    time_elapsed     | 6121     |
# |    total_timesteps  | 2096     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.27e-05 |
# |    n_updates        | 273      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1888     |
# |    fps              | 0        |
# |    time_elapsed     | 6134     |
# |    total_timesteps  | 2100     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000176 |
# |    n_updates        | 274      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1892     |
# |    fps              | 0        |
# |    time_elapsed     | 6147     |
# |    total_timesteps  | 2104     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000118 |
# |    n_updates        | 275      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1896     |
# |    fps              | 0        |
# |    time_elapsed     | 6161     |
# |    total_timesteps  | 2109     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.61e-05 |
# |    n_updates        | 277      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1900     |
# |    fps              | 0        |
# |    time_elapsed     | 6174     |
# |    total_timesteps  | 2113     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000133 |
# |    n_updates        | 278      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1904     |
# |    fps              | 0        |
# |    time_elapsed     | 6188     |
# |    total_timesteps  | 2118     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000149 |
# |    n_updates        | 279      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1908     |
# |    fps              | 0        |
# |    time_elapsed     | 6201     |
# |    total_timesteps  | 2122     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000166 |
# |    n_updates        | 280      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1912     |
# |    fps              | 0        |
# |    time_elapsed     | 6214     |
# |    total_timesteps  | 2126     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000135 |
# |    n_updates        | 281      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1916     |
# |    fps              | 0        |
# |    time_elapsed     | 6227     |
# |    total_timesteps  | 2130     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000163 |
# |    n_updates        | 282      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1920     |
# |    fps              | 0        |
# |    time_elapsed     | 6240     |
# |    total_timesteps  | 2134     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.2e-05  |
# |    n_updates        | 283      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1924     |
# |    fps              | 0        |
# |    time_elapsed     | 6253     |
# |    total_timesteps  | 2138     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000141 |
# |    n_updates        | 284      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1928     |
# |    fps              | 0        |
# |    time_elapsed     | 6266     |
# |    total_timesteps  | 2142     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000101 |
# |    n_updates        | 285      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.03     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1932     |
# |    fps              | 0        |
# |    time_elapsed     | 6279     |
# |    total_timesteps  | 2146     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.76e-05 |
# |    n_updates        | 286      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1936     |
# |    fps              | 0        |
# |    time_elapsed     | 6293     |
# |    total_timesteps  | 2152     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00017  |
# |    n_updates        | 287      |
# ----------------------------------
#
#
#
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1940     |
# |    fps              | 0        |
# |    time_elapsed     | 6307     |
# |    total_timesteps  | 2157     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000181 |
# |    n_updates        | 289      |
# ----------------------------------
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9384\2075645273.py in <module>
# ----> 1 agent.learn(total_timesteps=5000, callback=callback)
#
# ~\ENVS\dyno_ai\lib\site-packages\stable_baselines3\dqn\dqn.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     283             eval_log_path=eval_log_path,
#     284             reset_num_timesteps=reset_num_timesteps,
# --> 285             progress_bar=progress_bar,
#     286         )
#     287
#
# ~\ENVS\dyno_ai\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     361                 learning_starts=self.learning_starts,
#     362                 replay_buffer=self.replay_buffer,
# --> 363                 log_interval=log_interval,
#     364             )
#     365
#
# ~\ENVS\dyno_ai\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     587
#     588             # Rescale and perform action
# --> 589             new_obs, rewards, dones, infos = env.step(actions)
#     590
#     591             self.num_timesteps += env.num_envs
#
# ~\ENVS\dyno_ai\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# ~\ENVS\dyno_ai\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in step_wait(self)
#      47                 # save final observation where user can get it, then reset
#      48                 self.buf_infos[env_idx]["terminal_observation"] = obs
# ---> 49                 obs = self.envs[env_idx].reset()
#      50             self._save_obs(env_idx, obs)
#      51         return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# ~\ENVS\dyno_ai\lib\site-packages\stable_baselines3\common\monitor.py in reset(self, **kwargs)
#      81                 raise ValueError(f"Expected you to pass keyword argument {key} into reset")
#      82             self.current_reset_info[key] = value
# ---> 83         return self.env.reset(**kwargs)
#      84
#      85     def step(self, action: Union[np.ndarray, int]) -> GymStepReturn:
#
# ~\AppData\Local\Temp\ipykernel_9384\2639490622.py in reset(self)
#      13         pydirectinput.click(500,500)
#      14         time.sleep(2)
# ---> 15         pydirectinput.press("space")
#      16
#      17         return self.get_observation()
#
# ~\ENVS\dyno_ai\lib\site-packages\pydirectinput\__init__.py in wrapper(*args, **kwargs)
#     239         funcArgs = inspect.getcallargs(wrappedFunction, *args, **kwargs)
#     240
# --> 241         failSafeCheck()
#     242         returnVal = wrappedFunction(*args, **kwargs)
#     243         _handlePause(funcArgs.get("_pause"))
#
# ~\ENVS\dyno_ai\lib\site-packages\pydirectinput\__init__.py in failSafeCheck()
#     222     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
#     223         raise FailSafeException(
# --> 224             "PyDirectInput fail-safe triggered from mouse moving to a corner of the screen. To disable this " \
#     225             "fail-safe, set pydirectinput.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED."
#     226         )
#
# FailSafeException: PyDirectInput fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pydirectinput.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %%
obs = game.reset()

# %%
# loading the trained model
agent.load("train/best model_7000.zip")

# %%
# test the prediction
action, _ = agent.predict(obs)
print(action)
# Out:
# 1

# %%
for episodes in range(10):
    obs = game.reset()
    done = False
    total_reward = 0
    
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = game.step(int(action))
        total_reward += reward
        
    print(f'total reward for episode {episodes} is {total_reward}')
# Out:
# True
# total reward for episode 0 is 1
#
# True
# total reward for episode 1 is 1
#
# True
# total reward for episode 2 is 1
#
# True
# total reward for episode 3 is 1
#
# True
# total reward for episode 4 is 1
#
# True
# total reward for episode 5 is 1
#
# True
# total reward for episode 6 is 1
#
# True
# total reward for episode 7 is 1
#
# True
# total reward for episode 8 is 1
#
# True
# total reward for episode 9 is 1
